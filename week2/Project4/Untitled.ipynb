# %%
print('------Hi user, Welcome to Izifi Technology------')
name = input('What is your name')
age = input('how old are you')
experience= input('How many years of experience do you have')
atr=['N5,600,000','N4,480,000','N1,500,000','N550,000']

if age >= '55' and experience >= '25':
    print('Name:',name)
    print('Age:',age)
    print('Annual Tax Revenue:',atr[0])
elif age >='45' and experience >='20':
    print('Name:',name)
    print('Age:',age)
    print('Annual Tax Revenue:',atr[1])
elif age >= '35' and experience >= '10':
    print('Name:',name)
    print('Age:',age)
    print('Annual Tax Revenue:',atr[2])
else: 
    print('Name:',name)
    print('Age:',age)
    print('Annual Tax Revenue:',atr[3])
# Out:
# ------Hi user, Welcome to Izifi Technology------
# What is your name Chinyere Orji
# how old are you 40
# How many years of experience do you have 20
# Name: Chinyere Orji
# Age: 40
# Annual Tax Revenue: N1,500,000
