# %%
str= input('Enter your state of origin:')
print('your state of origin is:',str)
print('The firsr character is:',str[0])
print('The Character Starting from 3rd to 5th are:',str[2:5])
print('The string starting from 3rd character is:',str[2:])
print('State of Origin two times',str * 2)
# Out:
# Enter your state of origin: jigawa
# your state of origin is: jigawa
# The firsr character is: j
# The Character Starting from 3rd to 5th are: gaw
# The string starting from 3rd character is: gawa
# State of Origin two times jigawajigawa

# %%
#input from users
m=float(input('Enter mass in kilograms'))
#constant value for the speed of light in m/s
c= 299792458
#calculating energy using Einstein's equation
energy= m * c ** 2
#displaying results
print(f'The energy equivalent to {m} kg of mas is {energy} joules.')
# Out:
# Enter mass in kilograms 100
# The energy equivalent to 100.0 kg of mas is 8.987551787368176e+18 joules.

# %%
list= ['Anaconda', 786, 2.23, 'Jupyter',70.2]
shortlist = [321,'python']
print(list)
print(list[0])
print(list[1:3])
print(list[2:])
print(shortlist * 2)
print(list + shortlist)
# Out:
# ['Anaconda', 786, 2.23, 'Jupyter', 70.2]
# Anaconda
# [786, 2.23]
# [2.23, 'Jupyter', 70.2]
# [321, 'python', 321, 'python']
# ['Anaconda', 786, 2.23, 'Jupyter', 70.2, 321, 'python']

# %%
#convert to int
grade=int(70)
gpa=int(4.9)
cgpa=int('4')

print(f"Grade:{grade}")
print(f"GPA:{gpa}")
print(f"CGPA:{cgpa}")
# Out:
# Grade:70
# GPA:4
# CGPA:4

# %%
#convert to float
grade= float(97)
gpa= float(5)
cgpa=float("4.7")

print(f"Grade = {grade}")
print(f"GPA= {gpa}")
print(f"CGPA= {cgpa}")
# Out:
# Grade = 97.0
# GPA= 5.0
# CGPA= 4.7
