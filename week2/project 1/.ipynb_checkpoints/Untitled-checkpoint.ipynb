# %%
#PROJECT C
BEGIN
INPUT  NAME A
INPUT NAME B
INPUT AGE 1
INPUT AGE 2
TEMP = AGE 2
AGE 2= AGE 1
AGE 1 = TEMP
PRINT AGE 1
PRINT AGE 2
END

# %% [markdown]
# #P![Screenshot 2026-03-11 152431.png](attachment:1599f876-08de-4b1c-b017-90f1b5d9583c.png)ROJECT A
# BEGIN
# INPUT ITEM,ITEM PRICE,ITEM QUANTITY
# TOTAL PRICE = ITEM PRICE  * QUANTITY
# IF DISCOUTN CODE THEN
# COMPUTE DISCOUNT
# ELSE PRINT RECIEPT
# END

# %% [markdown]
# ![Screenshot 2026-03-11 153509.png](attachment:e10cfc82-6b55-4a98-b3b7-f10e21bf57e3.png)
